# %%
#%pip install tabula-py

# %%
import pandas as pd
import numpy as np
import re
from tabula import read_pdf

# %% [markdown]
# ## 1. Upload Data Source

# %% [markdown]
# #### Origin: Data Science Course Catalog

# %%
data_science_file = read_pdf("../data/origin/MK_MMDS_2022_23_neue_PO_29082022.pdf", pages="all")
data_science_file_copy = data_science_file.copy()
len(data_science_file)
# Out:
# 59

# %%
# Keep tables with information (>2)
df = []
for table in data_science_file_copy:
    if len(table)>2:
        df.append(table)
len(df)
# Out:
# 26

# %% [markdown]
# ## 2. Data Preprocessing

# %% [markdown]
# Data Frame Cleaning
# 1. Remove ['Language', 'ECTS', 'Page'] from df[x]
# 2. Promote first row as header
# 3. Insert module category as a new feature

# %% [markdown]
# ### Fundamentals Courses

# %%
df[1]
data_fundamentals = df[1].loc[:,~df[1].columns.isin(['Language', 'ECTS', 'Page','Unnamed: 2'])].copy()
data_fundamentals.columns = data_fundamentals.iloc[0]
data_fundamentals = data_fundamentals[2:]
data_fundamentals.columns = data_fundamentals.columns.fillna('module_code')
data_fundamentals['moduleCategory'] = 'Fundamentals'
data_fundamentals
# Out:
# 0 module_code                                  Name of Module Offered  \
# 2      CS 450                              Programming Course     HWS
# 3      CS 460                             Database Technology     FSS
# 4      CS 470                      Python for Data Scientists     FSS
# 5         NaN                           Multivariate Analyses     HWS
# 6         NaN                  Tutorial Multivariate Analyses     HWS
# 7         NaN  Empirische Methoden der Politik-\rwissenschaft     HWS
#
# 0 Language ECTS moduleCategory
# 2        E    6   Fundamentals
# 3        E    6   Fundamentals
# 4        E    6   Fundamentals
# 5        E    6   Fundamentals
# 6        E    2   Fundamentals
# 7      G/E    6   Fundamentals

# %% [markdown]
# ### Data Management Courses

# %%
df[8]
data_management = df[8].loc[:,~df[8].columns.isin(['Language', 'ECTS', 'Page'])].copy()
data_management.columns = data_management.iloc[0]
data_management = data_management[2:]
data_management.columns = data_management.columns.fillna('module_code')
data_management['moduleCategory'] = 'Data Management'
data_management
# Out:
# 0  module_code                          Name of Module  Offered Language  \
# 2       AC 651  Additional Course – Data Manage-\rment  HWS/FSS        E
# 3       CS 500           Advanced Software Engineering      HWS        E
# 4       CS 530                     Database Systems II      FSS        E
# 5       CS 550                            Algorithmics  FSS/HWS        E
# 6       CS 560             Large Scale Data Management      HWS        E
# 7       CS 600                Model-driven Development      HWS        E
# 8     CS 662**         Types and Programming Languages      HWS        E
# 9     IS 540**       Management of Enterprise\rSystems      HWS        E
# 10    IS 556**                      Public Blockchains      FSS        E
# 11      IE 630                      Query Optimization      FSS        E
# 12      IE 650                        Knowledge Graphs      HWS        E
# 13      IE 663   Information Retrieval and Web\rSearch      HWS        E
# 14      IE 670                    Web Data Integration      HWS        E
# 15      IE 691           Information Retrieval Project      HWS        E
# 16      IE 683            Web Data Integration Project      HWS        E
#
# 0       ECTS   moduleCategory
# 2   AC\r651*  Data Management
# 3          6  Data Management
# 4          6  Data Management
# 5          6  Data Management
# 6          6  Data Management
# 7          6  Data Management
# 8          6  Data Management
# 9          6  Data Management
# 10         3  Data Management
# 11         6  Data Management
# 12         6  Data Management
# 13         3  Data Management
# 14         3  Data Management
# 15         3  Data Management
# 16         3  Data Management

# %% [markdown]
# ### Data Analytics Courses

# %%
#Data Analystics
df[10]
data_analytics = df[10].loc[:,~df[10].columns.isin(['Language', 'ECTS', 'Page'])].copy()
data_analytics.columns = data_analytics.iloc[0]
data_analytics = data_analytics[2:]
data_analytics.columns = data_analytics.columns.fillna('module_code')
data_analytics['moduleCategory'] = 'Data Analytics'
data_analytics
# Out:
# 0  module_code                                     Name of Module    Offered  \
# 2       AC 652        Additional Course – Data Analytics\rMethods    HWS/FSS
# 3       DA 110           Computational Analysis of\rCommunication        HWS
# 4       IE 500                                      Data Mining I    HWS/FSS
# 5       IE 560                                   Decision Support        HWS
# 6       IE 661                                     Text Analytics        HWS
# 7       IE 671                                         Web Mining        FSS
# 8       IE 672                                     Data Mining II        FSS
# 9      IE 675b                                   Machine Learning        HWS
# 10      IE 676         Network Analysis replaced by IS\r622 (FSS)        HWS
# 11      IE 678                                      Deep Learning        FSS
# 12      IE 684                                 Web Mining Project        FSS
# 13      IE 692                            Advanced Process Mining        FSS
# 14      IE 694  Artificial Intelligence Applications\rin Industry        FSS
# 15      IE 696                Advanced Methods in Text\rAnalytics        FSS
# 16      IS 622                                  Network Science**        FSS
# 17     MAA 519                                Stochastic Calculus        HWS
# 18     MAB 504                        Mathematics and Information  irregular
# 19     MAB 508                             Algebraische Statistik  irregular
# 20     MAC 404                                        Optimierung        HWS
# 21     MAC 502                              Computational Finance        FSS
# 22     MAC 507                           Nichtlineare Optimierung        FSS
# 23     MAC 527                                   Markov Processes        FSS
# 24     MKT 511                                Marketing Analytics        FSS
# 25     MKT 545              Customers, Markets and Firm\rStrategy        FSS
#
# 0  Language      ECTS  moduleCategory
# 2         E  AC\r652*  Data Analytics
# 3         E         6  Data Analytics
# 4         E         6  Data Analytics
# 5         E         6  Data Analytics
# 6         E         6  Data Analytics
# 7         E         3  Data Analytics
# 8         E         6  Data Analytics
# 9         E         9  Data Analytics
# 10        E         6  Data Analytics
# 11        E         6  Data Analytics
# 12        E         3  Data Analytics
# 13        E         6  Data Analytics
# 14        E         6  Data Analytics
# 15        E         6  Data Analytics
# 16        E         6  Data Analytics
# 17        E         5  Data Analytics
# 18        G         8  Data Analytics
# 19      G/E         8  Data Analytics
# 20        G         8  Data Analytics
# 21      G/E         6  Data Analytics
# 22      G/E         6  Data Analytics
# 23        E         4  Data Analytics
# 24        E         6  Data Analytics
# 25        E         6  Data Analytics

# %% [markdown]
# ### Responsible Data Science Courses

# %%
df[15]
data_responsible = df[15].loc[:,~df[15].columns.isin(['Language', 'ECTS', 'Page'])].copy()
data_responsible.columns = data_responsible.iloc[0]
data_responsible = data_responsible[2:]
data_responsible.columns = data_responsible.columns.fillna('module_code')
data_responsible['moduleCategory'] = 'Responsible Data Science'
data_responsible
# Out:
# 0 module_code                               Name of Module Offered Language  \
# 2      CS 652                    Data Security and Privacy     FSS        E
# 3         NaN         Legal and Ethical Aspects of Privacy     HWS        E
# 4      CS 718  AI and Data Science in Fiction and\rSociety     HWS        E
#
# 0 ECTS            moduleCategory
# 2    6  Responsible Data Science
# 3    3  Responsible Data Science
# 4    4  Responsible Data Science

# %% [markdown]
# ### Consolidate Courses

# %%
final_frame = pd.concat([data_fundamentals,data_management,data_analytics,data_responsible],ignore_index=True,axis=0)

# Removing '\r' from the data
mask_r = final_frame['Name of Module'].str.contains('\r')
final_frame[mask_r]

# Final df cleaning
features = ['Name of Module','ECTS']
for col in features:
    final_frame.loc[mask_r,col] = final_frame.loc[mask_r,col].str.replace('\r',' ')
final_frame[mask_r]
for col in features:
    final_frame.loc[mask_r,col] = final_frame.loc[mask_r,col].str.replace('- ','')
final_frame[mask_r]

#Clean module_code
final_frame.module_code = final_frame.module_code.str.rstrip('**')
final_frame.module_code = final_frame.module_code.str.rstrip()
final_frame.module_code = final_frame.module_code.str.lstrip()
final_frame

final_frame
# Out:
# 0  module_code                                    Name of Module    Offered  \
# 0       CS 450                                Programming Course        HWS
# 1       CS 460                               Database Technology        FSS
# 2       CS 470                        Python for Data Scientists        FSS
# 3          NaN                             Multivariate Analyses        HWS
# 4          NaN                    Tutorial Multivariate Analyses        HWS
# 5          NaN       Empirische Methoden der Politikwissenschaft        HWS
# 6       AC 651               Additional Course – Data Management    HWS/FSS
# 7       CS 500                     Advanced Software Engineering        HWS
# 8       CS 530                               Database Systems II        FSS
# 9       CS 550                                      Algorithmics    FSS/HWS
# 10      CS 560                       Large Scale Data Management        HWS
# 11      CS 600                          Model-driven Development        HWS
# 12      CS 662                   Types and Programming Languages        HWS
# 13      IS 540                  Management of Enterprise Systems        HWS
# 14      IS 556                                Public Blockchains        FSS
# 15      IE 630                                Query Optimization        FSS
# 16      IE 650                                  Knowledge Graphs        HWS
# 17      IE 663              Information Retrieval and Web Search        HWS
# 18      IE 670                              Web Data Integration        HWS
# 19      IE 691                     Information Retrieval Project        HWS
# 20      IE 683                      Web Data Integration Project        HWS
# 21      AC 652        Additional Course – Data Analytics Methods    HWS/FSS
# 22      DA 110           Computational Analysis of Communication        HWS
# 23      IE 500                                     Data Mining I    HWS/FSS
# 24      IE 560                                  Decision Support        HWS
# 25      IE 661                                    Text Analytics        HWS
# 26      IE 671                                        Web Mining        FSS
# 27      IE 672                                    Data Mining II        FSS
# 28     IE 675b                                  Machine Learning        HWS
# 29      IE 676         Network Analysis replaced by IS 622 (FSS)        HWS
# 30      IE 678                                     Deep Learning        FSS
# 31      IE 684                                Web Mining Project        FSS
# 32      IE 692                           Advanced Process Mining        FSS
# 33      IE 694  Artificial Intelligence Applications in Industry        FSS
# 34      IE 696                Advanced Methods in Text Analytics        FSS
# 35      IS 622                                 Network Science**        FSS
# 36     MAA 519                               Stochastic Calculus        HWS
# 37     MAB 504                       Mathematics and Information  irregular
# 38     MAB 508                            Algebraische Statistik  irregular
# 39     MAC 404                                       Optimierung        HWS
# 40     MAC 502                             Computational Finance        FSS
# 41     MAC 507                          Nichtlineare Optimierung        FSS
# 42     MAC 527                                  Markov Processes        FSS
# 43     MKT 511                               Marketing Analytics        FSS
# 44     MKT 545              Customers, Markets and Firm Strategy        FSS
# 45      CS 652                         Data Security and Privacy        FSS
# 46         NaN              Legal and Ethical Aspects of Privacy        HWS
# 47      CS 718        AI and Data Science in Fiction and Society        HWS
#
# 0  Language     ECTS            moduleCategory
# 0         E        6              Fundamentals
# 1         E        6              Fundamentals
# 2         E        6              Fundamentals
# 3         E        6              Fundamentals
# 4         E        2              Fundamentals
# 5       G/E        6              Fundamentals
# 6         E  AC 651*           Data Management
# 7         E        6           Data Management
# 8         E        6           Data Management
# 9         E        6           Data Management
# 10        E        6           Data Management
# 11        E        6           Data Management
# 12        E        6           Data Management
# 13        E        6           Data Management
# 14        E        3           Data Management
# 15        E        6           Data Management
# 16        E        6           Data Management
# 17        E        3           Data Management
# 18        E        3           Data Management
# 19        E        3           Data Management
# 20        E        3           Data Management
# 21        E  AC 652*            Data Analytics
# 22        E        6            Data Analytics
# 23        E        6            Data Analytics
# 24        E        6            Data Analytics
# 25        E        6            Data Analytics
# 26        E        3            Data Analytics
# 27        E        6            Data Analytics
# 28        E        9            Data Analytics
# 29        E        6            Data Analytics
# 30        E        6            Data Analytics
# 31        E        3            Data Analytics
# 32        E        6            Data Analytics
# 33        E        6            Data Analytics
# 34        E        6            Data Analytics
# 35        E        6            Data Analytics
# 36        E        5            Data Analytics
# 37        G        8            Data Analytics
# 38      G/E        8            Data Analytics
# 39        G        8            Data Analytics
# 40      G/E        6            Data Analytics
# 41      G/E        6            Data Analytics
# 42        E        4            Data Analytics
# 43        E        6            Data Analytics
# 44        E        6            Data Analytics
# 45        E        6  Responsible Data Science
# 46        E        3  Responsible Data Science
# 47        E        4  Responsible Data Science

# %% [markdown]
# ## 3. Save MMDS_Courses

# %%
# Save file
final_frame.to_csv('../data/processed/mmds_courses.csv',index=False)
